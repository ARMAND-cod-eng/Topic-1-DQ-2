# %%
#import numpy and matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data for the two studies

# %%
sport = ['basketball', 'Soccer', 'Baseball']
study_1_percentages = [0.45, 0.30, 0.25]  # Results from study with 100 participants
study_2_percentages = [0.42, 0.32, 0.26]  # Results from study with 1000 participants

# %%
# Plotting the bars

# %%
plt.bar(r1, study_1_percentages, color='b', width=bar_width, edgecolor='grey', label='Study with 100 participants')
plt.bar(r2, study_2_percentages, color='r', width=bar_width, edgecolor='grey', label='Study with 1000 participants')

# Adding labels
plt.xlabel('GCU Sport', fontweight='bold')
plt.ylabel('Percentage of Students', fontweight='bold')
plt.xticks([r + bar_width/2 for r in range(len(sport))], sport)

# Adding a legend
plt.legend()

# Showing the plot
plt.title('Comparison of GCU Sport')
plt.show()
